# %%
import pandas as pd

# %%
sales     = pd.read_excel('data/satislar.xlsx',0)
products  = pd.read_excel('data/satislar.xlsx',1)
customers = pd.read_excel('data/satislar.xlsx',2)

# %%
customers
# Out:
#      Customer ID       Customer Name      Segment        Country  \
# 0       CG-12520         Claire Gute     Consumer  United States
# 1       CG-12520         Claire Gute     Consumer  United States
# 2       DV-13045     Darrin Van Huff    Corporate  United States
# 3       SO-20335      Sean O'Donnell     Consumer  United States
# 4       SO-20335      Sean O'Donnell     Consumer  United States
# 5       BH-11710     Brosina Hoffman     Consumer  United States
# 6       BH-11710     Brosina Hoffman     Consumer  United States
# 7       BH-11710     Brosina Hoffman     Consumer  United States
# 8       BH-11710     Brosina Hoffman     Consumer  United States
# 9       BH-11710     Brosina Hoffman     Consumer  United States
# 10      BH-11710     Brosina Hoffman     Consumer  United States
# 11      BH-11710     Brosina Hoffman     Consumer  United States
# 12      AA-10480        Andrew Allen     Consumer  United States
# ...

# %%
products
# Out:
#            Product ID         Category Sub-Category  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 1     FUR-CH-10000454        Furniture       Chairs
# 2     OFF-LA-10000240  Office Supplies       Labels
# 3     FUR-TA-10000577        Furniture       Tables
# 4     OFF-ST-10000760  Office Supplies      Storage
# 5     FUR-FU-10001487        Furniture  Furnishings
# 6     OFF-AR-10002833  Office Supplies          Art
# 7     TEC-PH-10002275       Technology       Phones
# 8     OFF-BI-10003910  Office Supplies      Binders
# 9     OFF-AP-10002892  Office Supplies   Appliances
# 10    FUR-TA-10001539        Furniture       Tables
# 11    TEC-PH-10002033       Technology       Phones
# 12    OFF-PA-10002365  Office Supplies        Paper
# 13    OFF-BI-10003656  Office Supplies      Binders
# 14    OFF-AP-10002311  Office Supplies   Appliances
# 15    OFF-BI-10000756  Office Supplies      Binders
# 16    OFF-ST-10004186  Office Supplies      Storage
# ...

# %%
sales.join(products,on='Product ID',how='outer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-9f6771c037b9> in <module>()
# ----> 1 sales.join(products,on='Product ID',how='outer')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6324         # For SparseDataFrame's benefit
#    6325         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6326                                  rsuffix=rsuffix, sort=sort)
#    6327
#    6328     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6339             return merge(self, other, left_on=on, how=how,
#    6340                          left_index=on is None, right_index=True,
# ...
